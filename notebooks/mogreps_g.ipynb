# %%
import intake

# %%
import os
import xarray as xr
import numpy as np
import intake
xr.set_options(display_style='text') # fix for display issue on AML CI
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = (15.0, 15.0)

# %%
ds_single_level = intake.open_catalog("../met_office_datasets/cats/mogreps_g/single_level_data.yaml").single_level.read_chunked()

# %%
for var in list(ds_single_level.data_vars):
    print(var)
    ds_single_level[var][3,3,0].plot()
    plt.show()
# Out:
# cloud_amount_of_low_cloud
# cloud_amount_of_medium_cloud
