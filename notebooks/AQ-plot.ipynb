# %%
import met_office_datasets
import os
import intake

# %%
cat_path = os.path.abspath(os.path.join(os.path.dirname("../met_office_datasets/air_quality_cat.yaml")))

# %%
cat = intake.open_catalog(cat_path)
aq_hourly = cat.air_quality_hourly.read_chunked()
aq_hourly
# Out:
# <xarray.Dataset>
# Dimensions:                  (projection_x_coordinate: 548, projection_y_coordinate: 704, time: 7528)
# Coordinates:
#   * projection_x_coordinate  (projection_x_coordinate) float64 -2.38e+05 ... ...
#   * projection_y_coordinate  (projection_y_coordinate) float64 -1.84e+05 ... ...
#   * time                     (time) datetime64[ns] 2020-01-01 ... 2020-11-09T...
# Data variables:
#     no2                      (time, projection_y_coordinate, projection_x_coordinate) float32 dask.array<chunksize=(24, 704, 548), meta=np.ndarray>
#     o3                       (time, projection_y_coordinate, projection_x_coordinate) float32 dask.array<chunksize=(24, 704, 548), meta=np.ndarray>
#     pm10                     (time, projection_y_coordinate, projection_x_coordinate) float32 dask.array<chunksize=(24, 704, 548), meta=np.ndarray>
#     pm2p5                    (time, projection_y_coordinate, projection_x_coordinate) float32 dask.array<chunksize=(24, 704, 548), meta=np.ndarray>
#     so2                      (time, projection_y_coordinate, projection_x_coordinate) float32 dask.array<chunksize=(24, 704, 548), meta=np.ndarray>

# %%
aq_hourly["o3"][0:8,:,:].mean(['time']).plot()

# %%
aq_daily = cat.air_quality_daily.read_chunked()
aq_daily
# Out:
# <xarray.Dataset>
# Dimensions:                  (projection_x_coordinate: 548, projection_y_coordinate: 704, time: 314)
# Coordinates:
#   * projection_x_coordinate  (projection_x_coordinate) float64 -2.38e+05 ... ...
#   * projection_y_coordinate  (projection_y_coordinate) float64 -1.84e+05 ... ...
#   * time                     (time) datetime64[ns] 2020-01-01 ... 2020-11-09
# Data variables:
#     daqi                     (time, projection_y_coordinate, projection_x_coordinate) float32 dask.array<chunksize=(1, 704, 548), meta=np.ndarray>

# %%
aq_daily.daqi[-10:].mean(['time']).plot()
